# %% [markdown]
# <a href="https://colab.research.google.com/github/ManojKesani/Multi_Object_Tracking_FairMOT/blob/master/U_tracking_FairMOT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/microsoft/FairMOT.git
# Out:
# Cloning into 'FairMOT'...
# remote: Enumerating objects: 167, done.
# remote: Counting objects: 100% (167/167), done.
# remote: Compressing objects: 100% (136/136), done.
# remote: Total 167 (delta 44), reused 134 (delta 27), pack-reused 0
# Receiving objects: 100% (167/167), 43.51 MiB | 37.15 MiB/s, done.
# Resolving deltas: 100% (44/44), done.

# %%
# %env PYTHONPATH=
# Out:
# env: PYTHONPATH=

# %%
# %%bash
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-4.5.4-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local
# wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX
# Out:
# PREFIX=/usr/local
# installing: python-3.6.5-hc3d631a_2 ...
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libstdcxx-ng-7.2.0-hdf63c60_3 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: ncurses-6.1-hf484d3e_0 ...
# installing: openssl-1.0.2o-h20670df_0 ...
# installing: tk-8.6.7-hc745277_3 ...
# installing: xz-5.2.4-h14c3975_4 ...
# installing: yaml-0.1.7-had09818_2 ...
# installing: zlib-1.2.11-ha838bed_2 ...
# installing: libedit-3.1.20170329-h6b74fdf_2 ...
# installing: readline-7.0-ha6073c6_4 ...
# installing: sqlite-3.23.1-he433501_0 ...
# installing: asn1crypto-0.24.0-py36_0 ...
# installing: certifi-2018.4.16-py36_0 ...
# installing: chardet-3.0.4-py36h0f667ec_1 ...
# installing: idna-2.6-py36h82fb2a8_1 ...
# installing: pycosat-0.6.3-py36h0a5515d_0 ...
# installing: pycparser-2.18-py36hf9f622e_1 ...
# installing: pysocks-1.6.8-py36_0 ...
# ...

# %%
# %%bash
# conda install --channel defaults conda python=3.6 --yes
# conda update --channel defaults --all --yes
# Out:
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#     - python=3.6
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     libstdcxx-ng-9.1.0         |       hdf63c60_0         4.0 MB
#     ncurses-6.2                |       he6710b0_1         1.1 MB
#     ruamel_yaml-0.15.87        |   py36h7b6447c_1         256 KB
#     conda-package-handling-1.6.1|   py36h7b6447c_0         886 KB
#     ld_impl_linux-64-2.33.1    |       h53a641e_7         645 KB
#     zlib-1.2.11                |       h7b6447c_3         120 KB
#     brotlipy-0.7.0             |py36h7b6447c_1000         348 KB
#     readline-8.0               |       h7b6447c_0         428 KB
#     pyopenssl-19.1.0           |             py_1          47 KB
#     requests-2.24.0            |             py_0          54 KB
# ...

# %%
import sys
_ = (sys.path.append("/usr/local/lib/python3.6/site-packages"))

# %%
# !conda install pytorch==1.2.0 torchvision==0.4.0 cudatoolkit=10.0 -c pytorch --yes
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - cudatoolkit=10.0
#     - pytorch==1.2.0
#     - torchvision==0.4.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |              mkl           6 KB
#     cudatoolkit-10.0.130       |                0       261.2 MB
#     freetype-2.10.2            |       h5ab3b9f_0         608 KB
#     intel-openmp-2020.2        |              254         786 KB
#     jpeg-9b                    |       h024ee3a_2         214 KB
#     lcms2-2.11                 |       h396b838_0         307 KB
#     libpng-1.6.37              |       hbc83047_0         278 KB
#     libtiff-4.1.0              |       h2733197_1         449 KB
#     lz4-c-1.9.2                |       he6710b0_1         190 KB
# ...

# %%
# %%bash
#
# pip install Cython
# pip install ipykernel
# pip install ffmpeg
#
# cd /content/FairMOT
# pip install -r requirements.txt
#
# cd /content/FairMOT/src/lib/models/networks/DCNv2
# sh make.sh
#
# cd /content/FairMOT
# mkdir output
#
# mkdir models
# cd /content/FairMOT/models
# !wget -O all_dla34.pth --no-check-certificate "https://drive.google.com/open?id=1udpOPum8fJdoEQm6n0jsIgMMViOMFinu"
# Out:
# ...
#   Created wheel for tornado: filename=tornado-6.0.4-cp36-cp36m-linux_x86_64.whl size=427688 sha256=5445cd354f2dbfd101e0e9acee87b5908673c57f1f5eb7a962ff108042d62ca7
#   Stored in directory: /root/.cache/pip/wheels/37/a7/db/2d592e44029ef817f3ef63ea991db34191cebaef087a96f505
# Successfully built tornado
# ...
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6083 sha256=93c3ebaf7bb8ba81a08f3a9ca242235b07b998e066d8c8a420df3b5041a4ab7a
#   Stored in directory: /root/.cache/pip/wheels/aa/0d/3c/5a9cbae53044e993a211358ddae115ce34bcbc29f7a3bd9155
# Successfully built ffmpeg
# ...
#   Created wheel for cython-bbox: filename=cython_bbox-0.1.3-cp36-cp36m-linux_x86_64.whl size=58933 sha256=bfe4520e756a009de7f26874bdd8600cbf513433ef572478546972c994e530e5
#   Stored in directory: /root/.cache/pip/wheels/9c/0f/31/b318c7caae421049697be57d5c917b0592b98e1a9ed3bf4da4
# ...

# %%
cd /content/FairMOT/src
# Out:
# /content/FairMOT/src

# %%
# !python demo.py mot --load_model ../models/all_dla34.pth --conf_thres 0.4 --input-video /content/FairMOT/videos/MOT16-03.mp4 --output-root /content/FairMOT/output
# Out:
# Fix size testing.
# training chunk_sizes: [6, 6]
# The output will be saved to  /content/FairMOT/src/lib/../../exp/mot/default
# heads {'hm': 1, 'wh': 2, 'id': 512, 'reg': 2}
# 2020-09-28 02:30:53 [INFO]: Starting tracking...
# Lenth of the video: 1500 frames
# Creating model...
# Downloading: "http://dl.yf.io/dla/models/imagenet/dla34-ba72cf86.pth" to /root/.cache/torch/checkpoints/dla34-ba72cf86.pth
# 100% 60.3M/60.3M [00:00<00:00, 94.7MB/s]
# loaded ../models/all_dla34.pth, epoch 10
# 2020-09-28 02:30:58 [INFO]: Processing frame 0 (100000.00 fps)
# 2020-09-28 02:31:03 [INFO]: Processing frame 20 (6.00 fps)
# 2020-09-28 02:31:06 [INFO]: Processing frame 40 (7.83 fps)
# 2020-09-28 02:31:09 [INFO]: Processing frame 60 (8.75 fps)
# 2020-09-28 02:31:12 [INFO]: Processing frame 80 (9.34 fps)
# 2020-09-28 02:31:15 [INFO]: Processing frame 100 (9.72 fps)
# 2020-09-28 02:31:18 [INFO]: Processing frame 120 (9.99 fps)
# 2020-09-28 02:31:22 [INFO]: Processing frame 140 (10.17 fps)
# ...

# %%
# Out:
# --2020-09-28 02:51:46--  https://drive.google.com/open?id=1udpOPum8fJdoEQm6n0jsIgMMViOMFinu
# Resolving drive.google.com (drive.google.com)... 74.125.20.102, 74.125.20.113, 74.125.20.100, ...
# Connecting to drive.google.com (drive.google.com)|74.125.20.102|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://drive.google.com/file/d/1udpOPum8fJdoEQm6n0jsIgMMViOMFinu/view?usp=drive_open [following]
# --2020-09-28 02:51:46--  https://drive.google.com/file/d/1udpOPum8fJdoEQm6n0jsIgMMViOMFinu/view?usp=drive_open
# Reusing existing connection to drive.google.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘all_dla34.pth’
#
# all_dla34.pth           [ <=>                ]  68.90K  --.-KB/s    in 0.03s
#
# 2020-09-28 02:51:46 (2.40 MB/s) - ‘all_dla34.pth’ saved [70551]
